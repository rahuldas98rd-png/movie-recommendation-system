# %% [markdown]
# # Importing required libraries

# %%
# Core
import os
import warnings

from sympy.physics.units import years

warnings.filterwarnings("ignore")

# Data
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Stats
from scipy import stats

# Display
pd.set_option('display.max_columns', 200)
pd.set_option('display.float_format', lambda x: f"{x:.3f}")
sns.set_style("whitegrid")

# %% [markdown]
# # Data Loading

# %%
FILEPATH="../data/raw/"

movies = pd.read_csv(FILEPATH+"movies.csv")

# %%
movies
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# # Data Cleaning

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %% [markdown]
# ### Missing values

# %%
movies.isnull().sum()
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# visualization of missing values with help of bar charts
plt.figure(figsize=(20,4))
bars = plt.bar(x=movies.isnull().sum().index,
       height=movies.isnull().sum().values,
       edgecolor='black',
       width=0.4,
       color='red')
plt.bar_label(bars,
              labels=movies.isnull().sum().values,
              label_type='edge')
plt.xlabel('Name of the Features')
plt.xticks(rotation=90)
plt.ylabel('Missing Value Count')
plt.title('VISUALIZATION OF MISSING VALUES USING BAR GRAPH')

os.makedirs("reports", exist_ok=True)
plt.savefig("reports/all_missing.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
movies['release_date'] = pd.to_datetime(movies['release_date'])

# %%
movies.dtypes
# Out:
# budget                           int64
# genres                          object
# homepage                        object
# id                               int64
# keywords                        object
# original_language               object
# original_title                  object
# overview                        object
# popularity                     float64
# production_companies            object
# production_countries            object
# release_date            datetime64[ns]
# revenue                          int64
# runtime                        float64
# spoken_languages                object
# status                          object
# tagline                         object
# title                           object
# vote_average                   float64
# vote_count                       int64
# dtype: object

# %%
movies[movies['release_date'].isnull()]
# Out:
#       budget genres homepage      id keywords original_language  \
# 4553       0     []      NaN  380097       []                en
#
#                   original_title  \
# 4553  America Is Still the Place
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...       0.000
#
#      production_companies production_countries release_date  revenue  runtime  \
# 4553                   []                   []          NaT        0    0.000
#
#      spoken_languages    status tagline                       title  \
# 4553               []  Released     NaN  America Is Still the Place
#
#       vote_average  vote_count
# 4553         0.000           0

# %%
years = sorted(set(movies['release_date'].dropna(axis=0).dt.year), reverse=True)
years
# Out:
# [2017,
#  2016,
#  2015,
#  2014,
#  2013,
#  2012,
#  2011,
#  2010,
#  2009,
#  2008,
#  2007,
#  2006,
#  2005,
#  2004,
#  2003,
#  2002,
#  2001,
#  2000,
#  1999,
#  1998,
#  1997,
#  1996,
#  1995,
#  1994,
#  1993,
#  1992,
#  1991,
#  1990,
#  1989,
#  1988,
#  1987,
#  1986,
#  1985,
#  1984,
#  1983,
#  1982,
#  1981,
#  1980,
#  1979,
#  1978,
#  1977,
#  1976,
#  1975,
#  1974,
#  1973,
#  1972,
#  1971,
#  1970,
#  1969,
#  1968,
#  1967,
#  1966,
#  1965,
#  1964,
#  1963,
#  1962,
#  1961,
#  1960,
#  1959,
#  1958,
#  1957,
#  1956,
#  1955,
#  1954,
#  1953,
#  1952,
#  1951,
#  1950,
#  1949,
#  1948,
#  1947,
#  1946,
#  1945,
#  1944,
#  1942,
#  1941,
#  1940,
#  1939,
#  1938,
#  1937,
#  1936,
#  1935,
#  1934,
#  1933,
#  1932,
#  1930,
#  1929,
#  1927,
#  1925,
#  1916]

# %%
movies['spoken_languages']
# Out:
# 0       [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1                [{"iso_639_1": "en", "name": "English"}]
# 2       [{"iso_639_1": "fr", "name": "Fran\u00e7ais"},...
# 3                [{"iso_639_1": "en", "name": "English"}]
# 4                [{"iso_639_1": "en", "name": "English"}]
#                               ...
# 4798        [{"iso_639_1": "es", "name": "Espa\u00f1ol"}]
# 4799                                                   []
# 4800             [{"iso_639_1": "en", "name": "English"}]
# 4801             [{"iso_639_1": "en", "name": "English"}]
# 4802             [{"iso_639_1": "en", "name": "English"}]
# Name: spoken_languages, Length: 4803, dtype: object

# %%
import json


def data_extraction(x):
    data_list = []
    x = json.loads(x)
    for i, item in enumerate(x):
        data_list.append(x[i]['name'])
    final_data = ', '.join(data_list)
    return final_data

# %%
movies.loc[:, 'spoken_languages_extracted'] = movies.loc[:, 'spoken_languages'].apply(lambda x: data_extraction(x))

# %%
movies.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'spoken_languages_extracted'],
#       dtype='object')

# %%
movies_final = movies[['title', 'genres', 'keywords', 'overview']]

# %%
movies_final.isnull().sum()
# Out:
# title       0
# genres      0
# keywords    0
# overview    3
# dtype: int64

# %%
# visualization of missing values with help of bar charts
plt.figure(figsize=(20,4))
bars = plt.bar(x=movies_final.isnull().sum().index,
       height=movies_final.isnull().sum().values,
       edgecolor='black',
       width=0.4,
       color='red')
plt.bar_label(bars,
              labels=movies_final.isnull().sum().values,
              label_type='edge')
plt.xlabel('Name of the Features')
plt.xticks(rotation=90)
plt.ylabel('Missing Value Count')
plt.title('VISUALIZATION OF MISSING VALUES USING BAR GRAPH')

os.makedirs("reports", exist_ok=True)
plt.savefig("reports/required_missing.png", dpi=300, bbox_inches="tight")

plt.show()

# %%
movies_final[movies_final['overview'].isnull()]
# Out:
#                                            title  \
# 2656  Chiamatemi Francesco - Il Papa della gente
# 4140                 To Be Frank, Sinatra at 100
# 4431                                 Food Chains
#
#                                    genres  \
# 2656        [{"id": 18, "name": "Drama"}]
# 4140  [{"id": 99, "name": "Documentary"}]
# 4431  [{"id": 99, "name": "Documentary"}]
#
#                                                keywords overview
# 2656  [{"id": 717, "name": "pope"}, {"id": 5565, "na...      NaN
# 4140  [{"id": 6027, "name": "music"}, {"id": 225822,...      NaN
# 4431                                                 []      NaN

# %% [markdown]
# ### Replacing missing values with empty strings

# %%
movies_final['overview'] = movies_final['overview'].fillna(value='')

# %%
movies_final.isnull().sum()
# Out:
# title       0
# genres      0
# keywords    0
# overview    0
# dtype: int64

# %%
movies_final.head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4  [{"id": 818, "name": "based on novel"}, {"id":...
#
# ...

# %% [markdown]
# ### Duplicated Values

# %%
# Checking for duplicated titles
movies_final.title.duplicated().value_counts()
# Out:
# title
# False    4800
# True        3
# Name: count, dtype: int64

# %%
movies_final[movies_final.title.duplicated(False)]
# Out:
#                 title                                             genres  \
# 972          The Host  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1359           Batman  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 2877         The Host  [{"id": 27, "name": "Horror"}, {"id": 18, "nam...
# 3647  Out of the Blue                      [{"id": 18, "name": "Drama"}]
# 3693  Out of the Blue                      [{"id": 18, "name": "Drama"}]
# 4267           Batman  [{"id": 10751, "name": "Family"}, {"id": 12, "...
#
#                                                keywords  \
# 972   [{"id": 818, "name": "based on novel"}, {"id":...
# 1359  [{"id": 848, "name": "double life"}, {"id": 84...
# 2877  [{"id": 1261, "name": "river"}, {"id": 1880, "...
# 3647  [{"id": 4470, "name": "punk"}, {"id": 10183, "...
# 3693  [{"id": 2658, "name": "new zealand"}, {"id": 3...
# 4267  [{"id": 339, "name": "submarine"}, {"id": 849,...
#
#                                                overview
# ...

# %%
EXPORT_FILEPATH="../data/cleaned/"

movies_final.to_csv(EXPORT_FILEPATH+"movie_data_cleaned.csv", index=False)

# %% [markdown]
# ### Conclusion drawn from EDA:
# 1. There are some missing values present in the "overview" feature. We can perform missing value imputation with empty string.
