# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Loading Required Datasets

# %%
FILEPATH="../data/raw/"

movies = pd.read_csv(FILEPATH+"movies.csv")
credits = pd.read_csv(FILEPATH+"credits.csv")
ratings = pd.read_csv(FILEPATH+"ratings.csv")

# %% [markdown]
# ## Dataset Overview

# %% [markdown]
# ### 1. Dataset = "credits"

# %%
print("No. of rows: {}\nNo. of columns: {}".format(movies.shape[0],movies.shape[1]))

display(movies.head())

# %%
movies.info()

# %%
movies.columns

# %%
print(type(movies.loc[0,'genres']))
movies.loc[0,'genres']

# %% [markdown]
# ### Converting string into json format

# %%
json.loads(movies.loc[0,'genres'])

# %%
# getting a brief overview of each column for the 1st row only
for col in movies.columns:
    print("{}:\n{}\n".format(col, movies.loc[0,col]))

# %% [markdown]
# ### 2. Dataset = "credits"

# %%
print("No. of rows: {}\nNo. of columns: {}".format(credits.shape[0],credits.shape[1]))

display(credits.head())

# %%
credits.info()

# %%
print(type(credits.loc[0,'cast']))
credits.loc[0,'cast']

# %% [markdown]
# ### Converting string into json format

# %%
json.loads(credits.loc[0,'crew'])

# %%
# getting a brief overview of each column for the 1st row only
for col in credits.columns:
    print("{}:\n{}\n".format(col, credits.loc[0,col]))

# %% [markdown]
# ### 3. Dataset = "ratings"

# %%
print("No. of rows: {}\nNo. of columns: {}".format(ratings.shape[0],ratings.shape[1]))

display(ratings.head())

# %%
ratings.info()

# %%
# getting a brief overview of each column for the 1st row only
for col in ratings.columns:
    print("{}:\n{}\n".format(col, ratings.loc[0,col]))

# %% [markdown]
# ### Conclusion:
# - After overviewing three datasets, primary conclusion is to use only movies dataset primarily to make a baseline recommendation model using meta data.
# - Meta Data:
#   * "Genres" + "Keywords" + "Overview"
